# %%
import os

data_dir = os.path.join(os.getcwd(), "data")
os.listdir(data_dir)
# Out:
# ['sample_submission.csv', 'test.csv', 'train.csv']

# %%
import pandas as pd

train = pd.read_csv(os.path.join(data_dir, "train.csv"), encoding="utf-8")
test = pd.read_csv(os.path.join(data_dir, "test.csv"), encoding="utf-8")
print("Train ", train.shape)
print("Test ", test.shape)

train.head().append(train.tail())
# Out:
# Train  (250000, 102)
# Test  (150000, 101)
#             id        f0   f1        f2        f3           f4        f5  \
# 0            0 -0.002350   59  0.766739 -1.350460     42.27270  16.68570
# 1            1  0.784462  145 -0.463845 -0.530421  27324.90000   3.47545
# 2            2  0.317816   19 -0.432571 -0.382644   1383.26000  19.71290
# 3            3  0.210753   17 -0.616454  0.946362   -119.25300   4.08235
# 4            4  0.439671   20  0.968126 -0.092546     74.30200  12.30650
# 249995  249995  0.923980    6  0.663212 -0.055120      6.61768   1.26619
# 249996  249996  0.243556    7 -0.557062  1.333470    -54.88610  17.58310
# 249997  249997  0.046023   53  0.462863  0.704034   2062.94000  14.58160
# 249998  249998  0.977330   12 -1.002880  0.576377   4741.16000  11.10090
# 249999  249999  0.244233   51  0.729304 -0.702592    197.46200  19.02400
#
#                f6        f7          f8  ...         f91        f92      f93  \
# 0        30.35990  1.267300    0.392007  ...   -42.43990  26.854000  1.45751
# 1       160.49800  0.828007    3.735860  ...  -184.13200   7.901370  1.70644
# 2        31.10260 -0.515354   34.430800  ...     7.43721  37.218100  3.25339
# 3       185.25700  1.383310  -47.521400  ...     9.66778   0.626942  1.49425
# 4        72.18600 -0.233964   24.399100  ...   290.65700  15.604300  1.73557
# 249995   40.44790  0.852375   25.522400  ...  3517.97000  18.534200  1.41936
# 249996  212.96400 -1.204750 -128.385000  ...  1945.81000  19.482200  1.60072
# 249997   11.42710 -0.509812   80.818000  ...   -28.46890  11.008200  1.61080
# 249998    3.81546  0.616191  118.902000  ...  -275.53700  21.985700  3.16051
# 249999   42.33370  0.465181 -115.398000  ...  5387.25000  38.574600  3.61783
#
#              f94        f95       f96       f97       f98        f99  loss
# 0       0.696161   0.941764  1.828470  0.924090  2.296580  10.489800    15
# 1      -0.494699  -2.058300  0.819184  0.439152  2.364700   1.143830     3
# 2       0.337934   0.615037  2.216760  0.745268  1.696790  12.305500     6
# 3       0.517513 -10.222100  2.627310  0.617270  1.456450  10.028800     2
# 4      -0.476668   1.390190  2.195740  0.826987  1.784850   7.071970     1
# 249995  0.607504   4.950780  2.853420  0.961882  1.068010   1.437650    11
# 249996 -0.154877   5.693280  1.994540  0.760925  1.427880   1.226720     5
# 249997 -0.350927  27.986900  1.012690  0.830533  1.005470   0.455332     1
# 249998  0.772058   2.592220  3.938260  0.697430  0.962347   7.415890    10
# 249999 -0.544969  -0.987695  1.871910  0.452516  0.935411  28.912200     7
#
# [10 rows x 102 columns]

# %%
# Check if there are any NaNs:
train.isna().astype(int).sum().max()
# Out:
# 0

# %%
y = train["loss"]
X = train[[c for c in train.columns if c not in ("id", "loss")]]

# %%
# Check distribution of y variable:
from functions import *

y_dist = plot_disrete_dist(y)

# %%
# Check distribution of all X features:
all_dists = plot_hist_all_features(X, bins=100)

# %%
power_describe(X, viz="bar")
# Out:
# <style type="text/css">
# #T_88bd0_row0_col1, #T_88bd0_row0_col5, #T_88bd0_row1_col1, #T_88bd0_row1_col5, #T_88bd0_row2_col1, #T_88bd0_row2_col5, #T_88bd0_row3_col1, #T_88bd0_row3_col5, #T_88bd0_row4_col1, #T_88bd0_row4_col5, #T_88bd0_row5_col1, #T_88bd0_row5_col5, #T_88bd0_row6_col1, #T_88bd0_row6_col5, #T_88bd0_row7_col1, #T_88bd0_row7_col5, #T_88bd0_row8_col1, #T_88bd0_row8_col5, #T_88bd0_row9_col1, #T_88bd0_row9_col5, #T_88bd0_row10_col1, #T_88bd0_row10_col5, #T_88bd0_row11_col1, #T_88bd0_row11_col5, #T_88bd0_row12_col1, #T_88bd0_row12_col5, #T_88bd0_row13_col1, #T_88bd0_row13_col5, #T_88bd0_row14_col1, #T_88bd0_row14_col5, #T_88bd0_row15_col1, #T_88bd0_row15_col5, #T_88bd0_row17_col1, #T_88bd0_row17_col5, #T_88bd0_row18_col1, #T_88bd0_row18_col5, #T_88bd0_row19_col1, #T_88bd0_row19_col5, #T_88bd0_row20_col1, #T_88bd0_row20_col5, #T_88bd0_row21_col1, #T_88bd0_row21_col5, #T_88bd0_row22_col1, #T_88bd0_row22_col5, #T_88bd0_row23_col1, #T_88bd0_row23_col5, #T_88bd0_row25_col1, #T_88bd0_row25_col5, #T_88bd0_row26_col1, #T_88bd0_row26_col5, #T_88bd0_row27_col1, #T_88bd0_row27_col5, #T_88bd0_row28_col1, #T_88bd0_row28_col5, #T_88bd0_row29_col1, #T_88bd0_row29_col5, #T_88bd0_row30_col1, #T_88bd0_row30_col5, #T_88bd0_row31_col1, #T_88bd0_row31_col5, #T_88bd0_row33_col1, #T_88bd0_row33_col5, #T_88bd0_row34_col1, #T_88bd0_row34_col5, #T_88bd0_row35_col1, #T_88bd0_row35_col5, #T_88bd0_row36_col1, #T_88bd0_row36_col5, #T_88bd0_row37_col1, #T_88bd0_row37_col5, #T_88bd0_row38_col1, #T_88bd0_row38_col5, #T_88bd0_row39_col1, #T_88bd0_row39_col5, #T_88bd0_row40_col1, #T_88bd0_row40_col5, #T_88bd0_row41_col1, #T_88bd0_row41_col5, #T_88bd0_row42_col1, #T_88bd0_row42_col5, #T_88bd0_row43_col1, #T_88bd0_row43_col5, #T_88bd0_row44_col1, #T_88bd0_row44_col5, #T_88bd0_row45_col1, #T_88bd0_row45_col5, #T_88bd0_row46_col1, #T_88bd0_row46_col5, #T_88bd0_row47_col1, #T_88bd0_row47_col5, #T_88bd0_row49_col1, #T_88bd0_row49_col5, #T_88bd0_row50_col1, #T_88bd0_row50_col5, #T_88bd0_row51_col1, #T_88bd0_row51_col5, #T_88bd0_row52_col1, #T_88bd0_row52_col5, #T_88bd0_row53_col1, #T_88bd0_row53_col5, #T_88bd0_row54_col1, #T_88bd0_row54_col5, #T_88bd0_row55_col1, #T_88bd0_row55_col5, #T_88bd0_row56_col1, #T_88bd0_row56_col5, #T_88bd0_row57_col1, #T_88bd0_row57_col5, #T_88bd0_row58_col1, #T_88bd0_row58_col5, #T_88bd0_row59_col1, #T_88bd0_row59_col5, #T_88bd0_row61_col1, #T_88bd0_row61_col5, #T_88bd0_row62_col1, #T_88bd0_row62_col5, #T_88bd0_row63_col1, #T_88bd0_row63_col5, #T_88bd0_row64_col1, #T_88bd0_row64_col5, #T_88bd0_row65_col1, #T_88bd0_row65_col5, #T_88bd0_row66_col1, #T_88bd0_row66_col5, #T_88bd0_row67_col1, #T_88bd0_row67_col5, #T_88bd0_row68_col1, #T_88bd0_row68_col5, #T_88bd0_row69_col1, #T_88bd0_row69_col5, #T_88bd0_row70_col1, #T_88bd0_row70_col5, #T_88bd0_row71_col1, #T_88bd0_row71_col5, #T_88bd0_row72_col1, #T_88bd0_row72_col5, #T_88bd0_row73_col1, #T_88bd0_row73_col5, #T_88bd0_row74_col1, #T_88bd0_row74_col5, #T_88bd0_row75_col1, #T_88bd0_row75_col5, #T_88bd0_row77_col1, #T_88bd0_row77_col5, #T_88bd0_row78_col1, #T_88bd0_row78_col5, #T_88bd0_row79_col1, #T_88bd0_row79_col5, #T_88bd0_row80_col1, #T_88bd0_row80_col5, #T_88bd0_row81_col1, #T_88bd0_row81_col5, #T_88bd0_row83_col1, #T_88bd0_row83_col5, #T_88bd0_row84_col1, #T_88bd0_row84_col5, #T_88bd0_row85_col1, #T_88bd0_row85_col5, #T_88bd0_row86_col1, #T_88bd0_row86_col5, #T_88bd0_row87_col1, #T_88bd0_row87_col5, #T_88bd0_row88_col1, #T_88bd0_row88_col5, #T_88bd0_row89_col1, #T_88bd0_row89_col5, #T_88bd0_row90_col1, #T_88bd0_row90_col5, #T_88bd0_row91_col1, #T_88bd0_row91_col5, #T_88bd0_row92_col1, #T_88bd0_row92_col5, #T_88bd0_row93_col1, #T_88bd0_row93_col5, #T_88bd0_row94_col1, #T_88bd0_row94_col5, #T_88bd0_row95_col1, #T_88bd0_row95_col5, #T_88bd0_row96_col1, #T_88bd0_row96_col5, #T_88bd0_row97_col1, #T_88bd0_row97_col5, #T_88bd0_row98_col1, #T_88bd0_row98_col5, #T_88bd0_row99_col1, #T_88bd0_row99_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 0.0%, #3a64a3 0.0%, #3a64a3 0.0%, transparent 0.0%);
# }
# #T_88bd0_row0_col2, #T_88bd0_row1_col2, #T_88bd0_row2_col2, #T_88bd0_row3_col2, #T_88bd0_row4_col2, #T_88bd0_row5_col2, #T_88bd0_row6_col2, #T_88bd0_row7_col2, #T_88bd0_row8_col2, #T_88bd0_row9_col2, #T_88bd0_row10_col2, #T_88bd0_row11_col2, #T_88bd0_row12_col2, #T_88bd0_row13_col2, #T_88bd0_row14_col2, #T_88bd0_row15_col2, #T_88bd0_row17_col2, #T_88bd0_row18_col2, #T_88bd0_row19_col2, #T_88bd0_row20_col2, #T_88bd0_row21_col2, #T_88bd0_row22_col2, #T_88bd0_row23_col2, #T_88bd0_row24_col2, #T_88bd0_row25_col2, #T_88bd0_row26_col2, #T_88bd0_row27_col2, #T_88bd0_row28_col2, #T_88bd0_row29_col2, #T_88bd0_row30_col2, #T_88bd0_row31_col2, #T_88bd0_row32_col2, #T_88bd0_row33_col2, #T_88bd0_row34_col2, #T_88bd0_row35_col2, #T_88bd0_row36_col2, #T_88bd0_row37_col2, #T_88bd0_row38_col2, #T_88bd0_row39_col2, #T_88bd0_row40_col2, #T_88bd0_row41_col2, #T_88bd0_row42_col2, #T_88bd0_row43_col2, #T_88bd0_row44_col2, #T_88bd0_row45_col2, #T_88bd0_row46_col2, #T_88bd0_row47_col2, #T_88bd0_row48_col2, #T_88bd0_row49_col2, #T_88bd0_row50_col2, #T_88bd0_row51_col2, #T_88bd0_row52_col2, #T_88bd0_row53_col2, #T_88bd0_row54_col2, #T_88bd0_row55_col2, #T_88bd0_row56_col2, #T_88bd0_row57_col2, #T_88bd0_row58_col2, #T_88bd0_row59_col2, #T_88bd0_row61_col2, #T_88bd0_row62_col2, #T_88bd0_row63_col2, #T_88bd0_row64_col2, #T_88bd0_row65_col2, #T_88bd0_row66_col2, #T_88bd0_row67_col2, #T_88bd0_row68_col2, #T_88bd0_row69_col2, #T_88bd0_row70_col2, #T_88bd0_row71_col2, #T_88bd0_row72_col2, #T_88bd0_row73_col2, #T_88bd0_row74_col2, #T_88bd0_row75_col2, #T_88bd0_row76_col2, #T_88bd0_row77_col2, #T_88bd0_row78_col2, #T_88bd0_row79_col2, #T_88bd0_row80_col2, #T_88bd0_row81_col2, #T_88bd0_row82_col2, #T_88bd0_row83_col2, #T_88bd0_row84_col2, #T_88bd0_row85_col2, #T_88bd0_row86_col2, #T_88bd0_row87_col2, #T_88bd0_row88_col2, #T_88bd0_row89_col2, #T_88bd0_row90_col2, #T_88bd0_row91_col2, #T_88bd0_row92_col2, #T_88bd0_row93_col2, #T_88bd0_row94_col2, #T_88bd0_row95_col2, #T_88bd0_row96_col2, #T_88bd0_row97_col2, #T_88bd0_row98_col2, #T_88bd0_row99_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3a64a3 0.0%, transparent 0.0%);
# }
# #T_88bd0_row16_col1, #T_88bd0_row16_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 0.0%, #3a64a3 0.0%, #3a64a3 0.2%, transparent 0.2%);
# }
# #T_88bd0_row16_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3a64a3 0.4%, transparent 0.4%);
# }
# #T_88bd0_row24_col1, #T_88bd0_row24_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#de2c37 0.0%, transparent 0.0%);
# }
# #T_88bd0_row32_col1, #T_88bd0_row32_col5, #T_88bd0_row48_col1, #T_88bd0_row48_col5, #T_88bd0_row76_col1, #T_88bd0_row76_col5, #T_88bd0_row82_col1, #T_88bd0_row82_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 0.0%, #de2c37 0.0%, #de2c37 0.0%, transparent 0.0%);
# }
# #T_88bd0_row60_col1, #T_88bd0_row60_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 0.0%, #3a64a3 0.0%, #3a64a3 100.0%, transparent 100.0%);
# }
# #T_88bd0_row60_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3a64a3 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_88bd0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >25%</th>
#       <th class="col_heading level0 col5" >50%</th>
#       <th class="col_heading level0 col6" >75%</th>
#       <th class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88bd0_level0_row0" class="row_heading level0 row0" >f0</th>
#       <td id="T_88bd0_row0_col0" class="data row0 col0" >250000.000000</td>
#       <td id="T_88bd0_row0_col1" class="data

# %% [markdown]
# Scales of features are very different - feature `f60` is completely dominating all other features. Need to apply scaler.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_sc = pd.DataFrame(scaler.fit_transform(X), index=X.index, columns=X.columns)
power_describe(X_sc, viz="bar", viz_cols = ["50%", "min", "max"])
# Out:
# <style type="text/css">
# #T_ea9d3_row0_col3, #T_ea9d3_row21_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 85.6%, #de2c37 85.6%, #de2c37 100.0%, transparent 100.0%);
# }
# #T_ea9d3_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 39.6%, #3a64a3 39.6%, #3a64a3 40.5%, transparent 40.5%);
# }
# #T_ea9d3_row0_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3a64a3 12.1%, transparent 12.1%);
# }
# #T_ea9d3_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 87.7%, #de2c37 87.7%, #de2c37 100.0%, transparent 100.0%);
# }
# #T_ea9d3_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 20.3%, #de2c37 20.3%, #de2c37 39.6%, transparent 39.6%);
# }
# #T_ea9d3_row1_col7, #T_ea9d3_row36_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3a64a3 34.7%, transparent 34.7%);
# }
# #T_ea9d3_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 53.8%, #de2c37 53.8%, #de2c37 100.0%, transparent 100.0%);
# }
# #T_ea9d3_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 39.6%, #3a64a3 39.6%, #3a64a3 48.3%, transparent 48.3%);
# }
# #T_ea9d3_row2_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3a64a3 48.5%, transparent 48.5%);
# }
# #T_ea9d3_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 85.3%, #de2c37 85.3%, #de2c37 100.0%, transparent 100.0%);
# }
# #T_ea9d3_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 35.0%, #de2c37 35.0%, #de2c37 39.6%, transparent 39.6%);
# }
# #T_ea9d3_row3_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3a64a3 13.7%, transparent 13.7%);
# }
# #T_ea9d3_row4_col3, #T_ea9d3_row13_col3, #T_ea9d3_row42_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 85.9%, #de2c37 85.9%, #de2c37 100.0%, transparent 100.0%);
# }
# #T_ea9d3_row4_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 5.1%, #de2c37 5.1%, #de2c37 39.6%, transparent 39.6%);
# }
# #T_ea9d3_row4_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3a64a3 37.5%, transparent 37.5%);
# }
# #T_ea9d3_row5_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 84.0%, #de2c37 84.0%, #de2c37 100.0%, transparent 100.0%);
# }
# #T_ea9d3_row5_col5, #T_ea9d3_row29_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 29.0%, #de2c37 29.0%, #de2c37 39.6%, transparent 39.6%);
# }
# #T_ea9d3_row5_col7, #T_ea9d3_row13_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3a64a3 32.6%, transparent 32.6%);
# }
# #T_ea9d3_row6_col3, #T_ea9d3_row44_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 91.4%, #de2c37 91.4%, #de2c37 100.0%, transparent 100.0%);
# }
# #T_ea9d3_row6_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.0%, #de2c37 8.0%, #de2c37 39.6%, transparent 39.6%);
# }
# #T_ea9d3_row6_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3a64a3 28.3%, transparent 28.3%);
# }
# #T_ea9d3_row7_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 57.6%, #de2c37 57.6%, #de2c37 100.0%, transparent 100.0%);
# }
# #T_ea9d3_row7_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 39.6%, #3a64a3 39.6%, #3a64a3 63.2%, transparent 63.2%);
# }
# #T_ea9d3_row7_col7, #T_ea9d3_row28_col7, #T_ea9d3_row95_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3a64a3 29.7%, transparent 29.7%);
# }
# #T_ea9d3_row8_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 60.2%, #de2c37 60.2%, #de2c37 100.0%, transparent 100.0%);
# }
# #T_ea9d3_row8_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 33.3%, #de2c37 33.3%, #de2c37 39.6%, transparent 39.6%);
# }
# #T_ea9d3_row8_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3a64a3 29.9%, transparent 29.9%);
# }
# #T_ea9d3_row9_col3, #T_ea9d3_row36_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 80.4%, #de2c37 80.4%, #de2c37 100.0%, transparent 100.0%);
# }
# #T_ea9d3_row9_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 23.7%, #de2c37 23.7%, #de2c37 39.6%, transparent 39.6%);
# }
# #T_ea9d3_row9_col7, #T_ea9d3_row30_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3a64a3 34.8%, transparent 34.8%);
# }
# #T_ea9d3_row10_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 67.6%, #de2c37 67.6%, #de2c37 100.0%, transparent 100.0%);
# }
# #T_ea9d3_row10_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 39.6%, #3a64a3 39.6%, #3a64a3 40.7%, transparent 40.7%);
# }
# #T_ea9d3_row10_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3a64a3 23.2%, transparent 23.2%);
# }
# #T_ea9d3_row11_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 84.1%, #de2c37 84.1%, #de2c37 100.0%, transparent 100.0%);
# }
# #T_ea9d3_row11_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 39.6%, #3a64a3 39.6%, #3a64a3 45.8%, transparent 45.8%);
# }
# #T_ea9d3_row11_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3a64a3 14.8%, transparent 14.8%);
# }
# #T_ea9d3_row12_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 84.8%, #de2c37 84.8%, #de2c37 100.0%, transparent 100.0%);
# }
# #T_ea9d3_row12_col5, #T_ea9d3_row89_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 4.6%, #de2c37 4.6%, #de2c37 39.6%, transparent 39.6%);
# }
# #T_ea9d3_row12_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3a64a3 17.1%, transparent 17.1%);
# }
# #T_ea9d3_row13_col5, #T_ea9d3_row46_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 26.8%, #de2c37 26.8%, #de2c37 39.6%, transparent 39.6%);
# }
# #T_ea9d3_row14_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 56.3%, #de2c37 56.3%, #de2c37 100.0%, transparent 100.0%);
# }
# #T_ea9d3_row14_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 39.6%, #3a64a3 39.6%, #3a64a3 64.7%, transparent 64.7%);
# }
# #T_ea9d3_row14_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3a64a3 37.4%, transparent 37.4%);
# }
# #T_ea9d3_row15_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 68.8%, #de2c37 68.8%, #de2c37 100.0%, transparent 100.0%);
# }
# #T_ea9d3_row15_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 20.7%, #de2c37 20.7%, #de2c37 39.6%, transparent 39.6%);
# }
# #T_ea9d3_row15_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3a64a3 37.6%, transparent 37.6%);
# }
# #T_ea9d3_row16_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 91.0%, #de2c37 91.0%, #de2c37 100.0%, transparent 100.0%);
# }
# #T_ea9d3_row16_col5, #T_ea9d3_row59_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 17.1%, #de2c37 17.1%, #de2c37 39.6%, transparent 39.6%);
# }
# #T_ea9d3_row16_col7, #T_ea9d3_row73_col7, #T_ea9d3_row84_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3a64a3 19.2%, transparent 19.2%);
# }
# #T_ea9d3_row17_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 74.1%, #de2c37 74.1%, #de2c37 100.0%, transparent 100.0%);
# }
# #T_ea9d3_row17_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 33.4%, #de2c37 33.4%, #de2c37 39.6%, transparent 39.6%);
# }
# #T_ea9d3_row17_col7 {
#   width: 10em;
#   hei

# %% [markdown]
# #### Observations
#
# * Several features (e.g. `f27`, `f86`) are skewed/have "weird" distributions since the median is very different from the mean.
# * Several features (e.g. `f2`, `f41`, `f77`, `f85`) have extreme outliers as min/max is very far from mean.
#
# Look at these in more detail.

# %%
weird_dist_hist = plot_hist_all_features(X[["f27", "f86"]], figsize=(5, 8), bins=1000)

# %%
outliers_hist = plot_hist_all_features(X[["f2", "f41", "f77", "f85"]], figsize=(18, 8), bins=1000)

# %% [markdown]
# Now look at the skewed data:

# %%
mean_mid_skew = plot_mean_med_diff_skew_analysis(X_sc, cutoff=0.4, bins=1000)

# %% [markdown]
# Inspect some of the discrete X features:

# %%
discrete_cols = discrete_columns(X)
print(discrete_cols)
# Out:
# {'f1': 289, 'f16': 247476, 'f27': 37471, 'f55': 4726, 'f60': 212504, 'f86': 329}

# %%
f1_vs_y = plot_discrete_x_vs_discrete_y(X["f1"], y, sort_by_y=False)

# %%
f86_vs_y = plot_discrete_x_vs_discrete_y(X["f86"], y, sort_by_y=False)

# %%
raise
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20972/2235509928.py in <module>
# ----> 1 raise
#
# RuntimeError: No active exception to reraise

# %%
# Correlations of all features:
from heatmap import corrplot

plt.figure(figsize=(10, 10))
corrplot(X.corr())

# %%
xy_scatters = scatter_all_features(X, y)

# %% [markdown]
# 2 interesting features stand out - f27 and f86. Closer look with more detailed histograms.

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 6))
_ =ax[0].hist(X["f27"], bins=100)
_ =ax[1].hist(X["f86"], bins=100)

# %% [markdown]
# Possibly split dataset using cutoff somewhere around 40k for f27:

# %%
f = X["f27"]
f[f <= 40000].max()

# %%
f[f > 40000].min()

# %%
# PCA projection to 2 dimensions for visualizing:
from sklearn.decomposition import PCA


model = PCA(n_components=2)
two_dim = model.fit_transform(X)
fig, ax = plt.subplots(figsize=(10, 10))
ax.scatter(two_dim[:, 0], two_dim[:, 1])

# %%
from sklearn.preprocessing import PowerTransformer

pt = PowerTransformer(method="yeo-johnson", standardize=True)
X_transformed = pt.fit_transform(X)
X_transformed = pd.DataFrame(X_transformed, index=X.index, columns=X.columns)

# %%
x_trans_hists = hist_all_features(X_transformed)

# %%
xy_scatters = scatter_all_features(X_transformed, y)
